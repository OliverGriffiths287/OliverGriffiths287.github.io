# %% [markdown]
# <a href="https://colab.research.google.com/github/OliverGriffiths287/OliverGriffiths287.github.io/blob/main/Portfolio_API_Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import altair as alt

# %%
### RUNNING OUR LOOP

# // Define our base url with the {} placeholder for the country code.
base_api = 'https://api.beta.ons.gov.uk/v1/data?uri=/economy/nationalaccounts/balanceofpayments/timeseries/{}/mret'

# // Create a list of countries we want to get data for:
codes = ['ko2o', 'ko3r', 'enys', 'chnd', 'enyp', 'erdv', 'fkmp', 'chnx', 'choc']
countries = ['Algeria', 'Ghana', 'Germany', 'Sweden', 'France', 'India', 'Brazil', 'Netherlands', 'Portugal']

# %%
response=requests.get(base_api.format("choc"))
data=response.json()
data.keys()
# Out:
# dict_keys(['years', 'quarters', 'months', 'sourceDatasets', 'relatedDatasets', 'relatedDocuments', 'versions', 'type', 'uri', 'description'])

# %% [markdown]
# This step was done manually by implementing each of the codes for each country as I struggled to get the api to download each country's data inidvidually. However, I used the loops below for the data from my Github page.

# %%
data['months']
# Out:
# [{'date': '1997 JAN',
#   'value': '141',
#   'label': '1997 JAN',
#   'year': '1997',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '1997 FEB',
#   'value': '137',
#   'label': '1997 FEB',
#   'year': '1997',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '1997 MAR',
#   'value': '143',
#   'label': '1997 MAR',
#   'year': '1997',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '1997 APR',
#   'value': '152',
#   'label': '1997 APR',
#   'year': '1997',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1997 MAY',
#   'value': '143',
#   'label': '1997 MAY',
#   'year': '1997',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '1997 JUN',
#   'value': '154',
#   'label': '1997 JUN',
#   'year': '1997',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '1997 JUL',
#   'value': '143',
#   'label': '1997 JUL',
#   'year': '1997',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1997 AUG',
#   'value': '152',
#   'label': '1997 AUG',
#   'year': '1997',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1997 SEP',
#   'value': '137',
#   'label': '1997 SEP',
#   'year': '1997',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '1997 OCT',
#   'value': '160',
#   'label': '1997 OCT',
#   'year': '1997',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '1997 NOV',
#   'value': '162',
#   'label': '1997 NOV',
#   'year': '1997',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '1997 DEC',
#   'value': '147',
#   'label': '1997 DEC',
#   'year': '1997',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1998 JAN',
#   'value': '140',
#   'label': '1998 JAN',
#   'year': '1998',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1998 FEB',
#   'value': '151',
#   'label': '1998 FEB',
#   'year': '1998',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '1998 MAR',
#   'value': '147',
#   'label': '1998 MAR',
#   'year': '1998',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '1998 APR',
#   'value': '155',
#   'label': '1998 APR',
#   'year': '1998',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '1998 MAY',
#   'value': '153',
#   'label': '1998 MAY',
#   'year': '1998',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1998 JUN',
#   'value': '145',
#   'label': '1998 JUN',
#   'year': '1998',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '1998 JUL',
#   'value': '149',
#   'label': '1998 JUL',
#   'year': '1998',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '1998 AUG',
#   'value': '153',
#   'label': '1998 AUG',
#   'year': '1998',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '1998 SEP',
#   'value': '152',
#   'label': '1998 SEP',
#   'year': '1998',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1998 OCT',
#   'value': '146',
#   'label': '1998 OCT',
#   'year': '1998',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '1998 NOV',
#   'value': '158',
#   'label': '1998 NOV',
#   'year': '1998',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '1998 DEC',
#   'value': '152',
#   'label': '1998 DEC',
#   'year': '1998',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1999 JAN',
#   'value': '155',
#   'label': '1999 JAN',
#   'year': '1999',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '1999 FEB',
#   'value': '154',
#   'label': '1999 FEB',
#   'year': '1999',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1999 MAR',
#   'value': '160',
#   'label': '1999 MAR',
#   'year': '1999',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '1999 APR',
#   'value': '151',
#   'label': '1999 APR',
#   'year': '1999',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1999 MAY',
#   'value': '155',
#   'label': '1999 MAY',
#   'year': '1999',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1999 JUN',
#   'value': '138',
#   'label': '1999 JUN',
#   'year': '1999',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '1999 JUL',
#   'value': '157',
#   'label': '1999 JUL',
#   'year': '1999',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1999 AUG',
#   'value': '155',
#   'label': '1999 AUG',
#   'year': '1999',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1999 SEP',
#   'value': '155',
#   'label': '1999 SEP',
#   'year': '1999',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '1999 OCT',
#   'value': '158',
#   'label': '1999 OCT',
#   'year': '1999',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1999 NOV',
#   'value': '151',
#   'label': '1999 NOV',
#   'year': '1999',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '1999 DEC',
#   'value': '153',
#   'label': '1999 DEC',
#   'year': '1999',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2000 JAN',
#   'value': '158',
#   'label': '2000 JAN',
#   'year': '2000',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2000 FEB',
#   'value': '146',
#   'label': '2000 FEB',
#   'year': '2000',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2000 MAR',
#   'value': '137',
#   'label': '2000 MAR',
#   'year': '2000',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2000 APR',
#   'value': '140',
#   'label': '2000 APR',
#   'year': '2000',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2000 MAY',
#   'value': '158',
#   'label': '2000 MAY',
#   'year': '2000',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2000 JUN',
#   'value': '145',
#   'label': '2000 JUN',
#   'year': '2000',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2000 JUL',
#   'value': '142',
#   'label': '2000 JUL',
#   'year': '2000',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2000 AUG',
#   'value': '140',
#   'label': '2000 AUG',
#   'year': '2000',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2000 SEP',
#   'value': '139',
#   'label': '2000 SEP',
#   'year': '2000',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2000 OCT',
#   'value': '140',
#   'label': '2000 OCT',
#   'year': '2000',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2000 NOV',
#   'value': '136',
#   'label': '2000 NOV',
#   'year': '2000',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2019-10-09T23:00:00.000Z'},
#  {'date': '2000 DEC',
#   'value': '143',
#   'label': '2000 DEC',
#   'year': '2000',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2001 JAN',
#   'value': '139',
#   'label': '2001 JAN',
#   'year': '2001',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2001 FEB',
#   'value': '142',
#   'label': '2001 FEB',
#   'year': '2001',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2001 MAR',
#   'value': '138',
#   'label': '2001 MAR',
#   'year': '2001',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2001 APR',
#   'value': '143',
#   'label': '2001 APR',
#   'year': '2001',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2001 MAY',
#   'value': '136',
#   'label': '2001 MAY',
#   'year': '2001',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2001 JUN',
#   'value': '143',
#   'label': '2001 JUN',
#   'year': '2001',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2001 JUL',
#   'value': '139',
#   'label': '2001 JUL',
#   'year': '2001',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2001 AUG',
#   'value': '137',
#   'label': '2001 AUG',
#   'year': '2001',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2001 SEP',
#   'value': '134',
#   'label': '2001 SEP',
#   'year': '2001',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2001 OCT',
#   'value': '135',
#   'label': '2001 OCT',
#   'year': '2001',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2001 NOV',
#   'value': '136',
#   'label': '2001 NOV',
#   'year': '2001',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2001 DEC',
#   'value': '123',
#   'label': '2001 DEC',
#   'year': '2001',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2002 JAN',
#   'value': '135',
#   'label': '2002 JAN',
#   'year': '2002',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2002 FEB',
#   'value': '139',
#   'label': '2002 FEB',
#   'year': '2002',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2002 MAR',
#   'value': '142',
#   'label': '2002 MAR',
#   'year': '2002',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2002 APR',
#   'value': '139',
#   'label': '2002 APR',
#   'year': '2002',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2002 MAY',
#   'value': '146',
#   'label': '2002 MAY',
#   'year': '2002',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2002 JUN',
#   'value': '131',
#   'label': '2002 JUN',
#   'year': '2002',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2002 JUL',
#   'value': '150',
#   'label': '2002 JUL',
#   'year': '2002',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2002 AUG',
#   'value': '150',
#   'label': '2002 AUG',
#   'year': '2002',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2002 SEP',
#   'value': '152',
#   'label': '2002 SEP',
#   'year': '2002',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2002 OCT',
#   'value': '145',
#   'label': '2002 OCT',
#   'year': '2002',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2002 NOV',
#   'value': '151',
#   'label': '2002 NOV',
#   'year': '2002',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2002 DEC',
#   'value': '155',
#   'label': '2002 DEC',
#   'year': '2002',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2003 JAN',
#   'value': '161',
#   'label': '2003 JAN',
#   'year': '2003',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2003 FEB',
#   'value': '160',
#   'label': '2003 FEB',
#   'year': '2003',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2003 MAR',
#   'value': '163',
#   'label': '2003 MAR',
#   'year': '2003',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2003 APR',
#   'value': '186',
#   'label': '2003 APR',
#   'year': '2003',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2003 MAY',
#   'value': '160',
#   'label': '2003 MAY',
#   'year': '2003',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2003 JUN',
#   'value': '167',
#   'label': '2003 JUN',
#   'year': '2003',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2003 JUL',
#   'value': '160',
#   'label': '2003 JUL',
#   'year': '2003',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2003 AUG',
#   'value': '153',
#   'label': '2003 AUG',
#   'year': '2003',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2003 SEP',
#   'value': '162',
#   'label': '2003 SEP',
#   'year': '2003',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2003 OCT',
#   'value': '171',
#   'label': '2003 OCT',
#   'year': '2003',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2003 NOV',
#   'value': '167',
#   'label': '2003 NOV',
#   'year': '2003',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2003 DEC',
#   'value': '160',
#   'label': '2003 DEC',
#   'year': '2003',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2004 JAN',
#   'value': '163',
#   'label': '2004 JAN',
#   'year': '2004',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2004 FEB',
#   'value': '165',
#   'label': '2004 FEB',
#   'year': '2004',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2004 MAR',
#   'value': '169',
#   'label': '2004 MAR',
#   'year': '2004',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2004 APR',
#   'value': '161',
#   'label': '2004 APR',
#   'year': '2004',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2004 MAY',
#   'value': '165',
#   'label': '2004 MAY',
#   'year': '2004',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2004 JUN',
#   'value': '158',
#   'label': '2004 JUN',
#   'year': '2004',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2004 JUL',
#   'value': '169',
#   'label': '2004 JUL',
#   'year': '2004',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2004 AUG',
#   'value': '152',
#   'label': '2004 AUG',
#   'year': '2004',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2004 SEP',
#   'value': '159',
#   'label': '2004 SEP',
#   'year': '2004',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2004 OCT',
#   'value': '154',
#   'label': '2004 OCT',
#   'year': '2004',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2004 NOV',
#   'value': '163',
#   'label': '2004 NOV',
#   'year': '2004',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2004 DEC',
#   'value': '152',
#   'label': '2004 DEC',
#   'year': '2004',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2005 JAN',
#   'value': '149',
#   'label': '2005 JAN',
#   'year': '2005',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2005 FEB',
#   'value': '159',
#   'label': '2005 FEB',
#   'year': '2005',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2005 MAR',
#   'value': '144',
#   'label': '2005 MAR',
#   'year': '2005',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2005 APR',
#   'value': '152',
#   'label': '2005 APR',
#   'year': '2005',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2005 MAY',
#   'value': '168',
#   'label': '2005 MAY',
#   'year': '2005',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2019-10-09T23:00:00.000Z'},
#  {'date': '2005 JUN',
#   'value': '154',
#   'label': '2005 JUN',
#   'year': '2005',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2005 JUL',
#   'value': '143',
#   'label': '2005 JUL',
#   'year': '2005',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2005 AUG',
#   'value': '169',
#   'label': '2005 AUG',
#   'year': '2005',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2005 SEP',
#   'value': '191',
#   'label': '2005 SEP',
#   'year': '2005',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2005 OCT',
#   'value': '173',
#   'label': '2005 OCT',
#   'year': '2005',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2005 NOV',
#   'value': '239',
#   'label': '2005 NOV',
#   'year': '2005',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2005 DEC',
#   'value': '177',
#   'label': '2005 DEC',
#   'year': '2005',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2006 JAN',
#   'value': '323',
#   'label': '2006 JAN',
#   'year': '2006',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2006 FEB',
#   'value': '438',
#   'label': '2006 FEB',
#   'year': '2006',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2006 MAR',
#   'value': '285',
#   'label': '2006 MAR',
#   'year': '2006',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2006 APR',
#   'value': '641',
#   'label': '2006 APR',
#   'year': '2006',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2006 MAY',
#   'value': '641',
#   'label': '2006 MAY',
#   'year': '2006',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2006 JUN',
#   'value': '843',
#   'label': '2006 JUN',
#   'year': '2006',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2006 JUL',
#   'value': '355',
#   'label': '2006 JUL',
#   'year': '2006',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2006 AUG',
#   'value': '147',
#   'label': '2006 AUG',
#   'year': '2006',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2006 SEP',
#   'value': '135',
#   'label': '2006 SEP',
#   'year': '2006',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2006 OCT',
#   'value': '141',
#   'label': '2006 OCT',
#   'year': '2006',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2006 NOV',
#   'value': '135',
#   'label': '2006 NOV',
#   'year': '2006',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2020-10-08T23:00:00.000Z'},
#  {'date': '2006 DEC',
#   'value': '137',
#   'label': '2006 DEC',
#   'year': '2006',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2007 JAN',
#   'value': '129',
#   'label': '2007 JAN',
#   'year': '2007',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2020-10-08T23:00:00.000Z'},
#  {'date': '2007 FEB',
#   'value': '107',
#   'label': '2007 FEB',
#   'year': '2007',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2007 MAR',
#   'value': '129',
#   'label': '2007 MAR',
#   'year': '2007',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2007 APR',
#   'value': '130',
#   'label': '2007 APR',
#   'year': '2007',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2007 MAY',
#   'value': '120',
#   'label': '2007 MAY',
#   'year': '2007',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2007 JUN',
#   'value': '128',
#   'label': '2007 JUN',
#   'year': '2007',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2007 JUL',
#   'value': '117',
#   'label': '2007 JUL',
#   'year': '2007',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2007 AUG',
#   'value': '124',
#   'label': '2007 AUG',
#   'year': '2007',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2007 SEP',
#   'value': '131',
#   'label': '2007 SEP',
#   'year': '2007',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2007 OCT',
#   'value': '113',
#   'label': '2007 OCT',
#   'year': '2007',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2007 NOV',
#   'value': '122',
#   'label': '2007 NOV',
#   'year': '2007',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2018-07-09T23:00:00.000Z'},
#  {'date': '2007 DEC',
#   'value': '125',
#   'label': '2007 DEC',
#   'year': '2007',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2008 JAN',
#   'value': '130',
#   'label': '2008 JAN',
#   'year': '2008',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2008 FEB',
#   'value': '144',
#   'label': '2008 FEB',
#   'year': '2008',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2008 MAR',
#   'value': '135',
#   'label': '2008 MAR',
#   'year': '2008',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2008 APR',
#   'value': '125',
#   'label': '2008 APR',
#   'year': '2008',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2008 MAY',
#   'value': '145',
#   'label': '2008 MAY',
#   'year': '2008',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2008 JUN',
#   'value': '134',
#   'label': '2008 JUN',
#   'year': '2008',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2008 JUL',
#   'value': '147',
#   'label': '2008 JUL',
#   'year': '2008',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2008 AUG',
#   'value': '187',
#   'label': '2008 AUG',
#   'year': '2008',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2008 SEP',
#   'value': '143',
#   'label': '2008 SEP',
#   'year': '2008',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2008 OCT',
#   'value': '139',
#   'label': '2008 OCT',
#   'year': '2008',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2008 NOV',
#   'value': '136',
#   'label': '2008 NOV',
#   'year': '2008',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2008 DEC',
#   'value': '130',
#   'label': '2008 DEC',
#   'year': '2008',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2009 JAN',
#   'value': '102',
#   'label': '2009 JAN',
#   'year': '2009',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2009 FEB',
#   'value': '111',
#   'label': '2009 FEB',
#   'year': '2009',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2009 MAR',
#   'value': '101',
#   'label': '2009 MAR',
#   'year': '2009',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2009 APR',
#   'value': '126',
#   'label': '2009 APR',
#   'year': '2009',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2009 MAY',
#   'value': '109',
#   'label': '2009 MAY',
#   'year': '2009',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2009 JUN',
#   'value': '112',
#   'label': '2009 JUN',
#   'year': '2009',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2020-10-08T23:00:00.000Z'},
#  {'date': '2009 JUL',
#   'value': '113',
#   'label': '2009 JUL',
#   'year': '2009',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2009 AUG',
#   'value': '112',
#   'label': '2009 AUG',
#   'year': '2009',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2009 SEP',
#   'value': '122',
#   'label': '2009 SEP',
#   'year': '2009',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2009 OCT',
#   'value': '125',
#   'label': '2009 OCT',
#   'year': '2009',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2009 NOV',
#   'value': '122',
#   'label': '2009 NOV',
#   'year': '2009',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2009 DEC',
#   'value': '149',
#   'label': '2009 DEC',
#   'year': '2009',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2010 JAN',
#   'value': '121',
#   'label': '2010 JAN',
#   'year': '2010',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2010 FEB',
#   'value': '123',
#   'label': '2010 FEB',
#   'year': '2010',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2010 MAR',
#   'value': '189',
#   'label': '2010 MAR',
#   'year': '2010',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2010 APR',
#   'value': '144',
#   'label': '2010 APR',
#   'year': '2010',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2010 MAY',
#   'value': '134',
#   'label': '2010 MAY',
#   'year': '2010',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2010 JUN',
#   'value': '145',
#   'label': '2010 JUN',
#   'year': '2010',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2010 JUL',
#   'value': '149',
#   'label': '2010 JUL',
#   'year': '2010',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2010 AUG',
#   'value': '159',
#   'label': '2010 AUG',
#   'year': '2010',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2010 SEP',
#   'value': '130',
#   'label': '2010 SEP',
#   'year': '2010',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2010 OCT',
#   'value': '140',
#   'label': '2010 OCT',
#   'year': '2010',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2010 NOV',
#   'value': '142',
#   'label': '2010 NOV',
#   'year': '2010',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2010 DEC',
#   'value': '132',
#   'label': '2010 DEC',
#   'year': '2010',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2011 JAN',
#   'value': '162',
#   'label': '2011 JAN',
#   'year': '2011',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2011 FEB',
#   'value': '146',
#   'label': '2011 FEB',
#   'year': '2011',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2011 MAR',
#   'value': '141',
#   'label': '2011 MAR',
#   'year': '2011',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2011 APR',
#   'value': '143',
#   'label': '2011 APR',
#   'year': '2011',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2011 MAY',
#   'value': '172',
#   'label': '2011 MAY',
#   'year': '2011',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2019-10-09T23:00:00.000Z'},
#  {'date': '2011 JUN',
#   'value': '142',
#   'label': '2011 JUN',
#   'year': '2011',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2011 JUL',
#   'value': '139',
#   'label': '2011 JUL',
#   'year': '2011',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2011 AUG',
#   'value': '142',
#   'label': '2011 AUG',
#   'year': '2011',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2011 SEP',
#   'value': '154',
#   'label': '2011 SEP',
#   'year': '2011',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2011 OCT',
#   'value': '154',
#   'label': '2011 OCT',
#   'year': '2011',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2011 NOV',
#   'value': '139',
#   'label': '2011 NOV',
#   'year': '2011',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2020-10-08T23:00:00.000Z'},
#  {'date': '2011 DEC',
#   'value': '150',
#   'label': '2011 DEC',
#   'year': '2011',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2019-10-09T23:00:00.000Z'},
#  {'date': '2012 JAN',
#   'value': '155',
#   'label': '2012 JAN',
#   'year': '2012',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2012 FEB',
#   'value': '132',
#   'label': '2012 FEB',
#   'year': '2012',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2012 MAR',
#   'value': '166',
#   'label': '2012 MAR',
#   'year': '2012',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2012 APR',
#   'value': '132',
#   'label': '2012 APR',
#   'year': '2012',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2012 MAY',
#   'value': '136',
#   'label': '2012 MAY',
#   'year': '2012',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2012 JUN',
#   'value': '142',
#   'label': '2012 JUN',
#   'year': '2012',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2012 JUL',
#   'value': '147',
#   'label': '2012 JUL',
#   'year': '2012',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2012 AUG',
#   'value': '137',
#   'label': '2012 AUG',
#   'year': '2012',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2012 SEP',
#   'value': '130',
#   'label': '2012 SEP',
#   'year': '2012',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2012 OCT',
#   'value': '136',
#   'label': '2012 OCT',
#   'year': '2012',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2012 NOV',
#   'value': '153',
#   'label': '2012 NOV',
#   'year': '2012',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2012 DEC',
#   'value': '179',
#   'label': '2012 DEC',
#   'year': '2012',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2013 JAN',
#   'value': '139',
#   'label': '2013 JAN',
#   'year': '2013',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2013 FEB',
#   'value': '160',
#   'label': '2013 FEB',
#   'year': '2013',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2013 MAR',
#   'value': '149',
#   'label': '2013 MAR',
#   'year': '2013',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2013 APR',
#   'value': '157',
#   'label': '2013 APR',
#   'year': '2013',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2018-07-09T23:00:00.000Z'},
#  {'date': '2013 MAY',
#   'value': '157',
#   'label': '2013 MAY',
#   'year': '2013',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2013 JUN',
#   'value': '154',
#   'label': '2013 JUN',
#   'year': '2013',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2013 JUL',
#   'value': '150',
#   'label': '2013 JUL',
#   'year': '2013',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2013 AUG',
#   'value': '189',
#   'label': '2013 AUG',
#   'year': '2013',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2013 SEP',
#   'value': '172',
#   'label': '2013 SEP',
#   'year': '2013',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2013 OCT',
#   'value': '162',
#   'label': '2013 OCT',
#   'year': '2013',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2013 NOV',
#   'value': '175',
#   'label': '2013 NOV',
#   'year': '2013',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2013 DEC',
#   'value': '182',
#   'label': '2013 DEC',
#   'year': '2013',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2014 JAN',
#   'value': '185',
#   'label': '2014 JAN',
#   'year': '2014',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2014 FEB',
#   'value': '175',
#   'label': '2014 FEB',
#   'year': '2014',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2014 MAR',
#   'value': '172',
#   'label': '2014 MAR',
#   'year': '2014',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2014 APR',
#   'value': '182',
#   'label': '2014 APR',
#   'year': '2014',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2014 MAY',
#   'value': '189',
#   'label': '2014 MAY',
#   'year': '2014',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2014 JUN',
#   'value': '189',
#   'label': '2014 JUN',
#   'year': '2014',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2014 JUL',
#   'value': '189',
#   'label': '2014 JUL',
#   'year': '2014',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2014 AUG',
#   'value': '193',
#   'label': '2014 AUG',
#   'year': '2014',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2014 SEP',
#   'value': '191',
#   'label': '2014 SEP',
#   'year': '2014',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2014 OCT',
#   'value': '200',
#   'label': '2014 OCT',
#   'year': '2014',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2014 NOV',
#   'value': '187',
#   'label': '2014 NOV',
#   'year': '2014',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2014 DEC',
#   'value': '195',
#   'label': '2014 DEC',
#   'year': '2014',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2015 JAN',
#   'value': '184',
#   'label': '2015 JAN',
#   'year': '2015',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2015 FEB',
#   'value': '201',
#   'label': '2015 FEB',
#   'year': '2015',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2015 MAR',
#   'value': '198',
#   'label': '2015 MAR',
#   'year': '2015',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2020-10-08T23:00:00.000Z'},
#  {'date': '2015 APR',
#   'value': '203',
#   'label': '2015 APR',
#   'year': '2015',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2015 MAY',
#   'value': '190',
#   'label': '2015 MAY',
#   'year': '2015',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2015 JUN',
#   'value': '196',
#   'label': '2015 JUN',
#   'year': '2015',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2015 JUL',
#   'value': '184',
#   'label': '2015 JUL',
#   'year': '2015',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2015 AUG',
#   'value': '193',
#   'label': '2015 AUG',
#   'year': '2015',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2015 SEP',
#   'value': '195',
#   'label': '2015 SEP',
#   'year': '2015',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2015 OCT',
#   'value': '201',
#   'label': '2015 OCT',
#   'year': '2015',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2015 NOV',
#   'value': '204',
#   'label': '2015 NOV',
#   'year': '2015',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2015 DEC',
#   'value': '181',
#   'label': '2015 DEC',
#   'year': '2015',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2016 JAN',
#   'value': '194',
#   'label': '2016 JAN',
#   'year': '2016',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2016 FEB',
#   'value': '194',
#   'label': '2016 FEB',
#   'year': '2016',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2016 MAR',
#   'value': '202',
#   'label': '2016 MAR',
#   'year': '2016',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2016 APR',
#   'value': '244',
#   'label': '2016 APR',
#   'year': '2016',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2016 MAY',
#   'value': '218',
#   'label': '2016 MAY',
#   'year': '2016',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2016 JUN',
#   'value': '210',
#   'label': '2016 JUN',
#   'year': '2016',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2016 JUL',
#   'value': '235',
#   'label': '2016 JUL',
#   'year': '2016',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2016 AUG',
#   'value': '218',
#   'label': '2016 AUG',
#   'year': '2016',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2016 SEP',
#   'value': '226',
#   'label': '2016 SEP',
#   'year': '2016',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2021-10-12T23:00:00.000Z'},
#  {'date': '2016 OCT',
#   'value': '225',
#   'label': '2016 OCT',
#   'year': '2016',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2016 NOV',
#   'value': '249',
#   'label': '2016 NOV',
#   'year': '2016',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2016 DEC',
#   'value': '244',
#   'label': '2016 DEC',
#   'year': '2016',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2017 JAN',
#   'value': '252',
#   'label': '2017 JAN',
#   'year': '2017',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2017 FEB',
#   'value': '233',
#   'label': '2017 FEB',
#   'year': '2017',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2017 MAR',
#   'value': '256',
#   'label': '2017 MAR',
#   'year': '2017',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2017 APR',
#   'value': '239',
#   'label': '2017 APR',
#   'year': '2017',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2017 MAY',
#   'value': '236',
#   'label': '2017 MAY',
#   'year': '2017',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2017 JUN',
#   'value': '279',
#   'label': '2017 JUN',
#   'year': '2017',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2017 JUL',
#   'value': '258',
#   'label': '2017 JUL',
#   'year': '2017',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2017 AUG',
#   'value': '277',
#   'label': '2017 AUG',
#   'year': '2017',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2017 SEP',
#   'value': '259',
#   'label': '2017 SEP',
#   'year': '2017',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2017 OCT',
#   'value': '255',
#   'label': '2017 OCT',
#   'year': '2017',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2017 NOV',
#   'value': '243',
#   'label': '2017 NOV',
#   'year': '2017',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2017 DEC',
#   'value': '220',
#   'label': '2017 DEC',
#   'year': '2017',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2018 JAN',
#   'value': '249',
#   'label': '2018 JAN',
#   'year': '2018',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2018 FEB',
#   'value': '263',
#   'label': '2018 FEB',
#   'year': '2018',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2018 MAR',
#   'value': '262',
#   'label': '2018 MAR',
#   'year': '2018',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2018 APR',
#   'value': '263',
#   'label': '2018 APR',
#   'year': '2018',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2018 MAY',
#   'value': '257',
#   'label': '2018 MAY',
#   'year': '2018',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2018 JUN',
#   'value': '241',
#   'label': '2018 JUN',
#   'year': '2018',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2018 JUL',
#   'value': '270',
#   'label': '2018 JUL',
#   'year': '2018',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2018 AUG',
#   'value': '233',
#   'label': '2018 AUG',
#   'year': '2018',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2018 SEP',
#   'value': '265',
#   'label': '2018 SEP',
#   'year': '2018',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2018 OCT',
#   'value': '281',
#   'label': '2018 OCT',
#   'year': '2018',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2018 NOV',
#   'value': '261',
#   'label': '2018 NOV',
#   'year': '2018',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2018 DEC',
#   'value': '261',
#   'label': '2018 DEC',
#   'year': '2018',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2019 JAN',
#   'value': '302',
#   'label': '2019 JAN',
#   'year': '2019',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2019 FEB',
#   'value': '311',
#   'label': '2019 FEB',
#   'year': '2019',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2019 MAR',
#   'value': '280',
#   'label': '2019 MAR',
#   'year': '2019',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2019 APR',
#   'value': '261',
#   'label': '2019 APR',
#   'year': '2019',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2019 MAY',
#   'value': '280',
#   'label': '2019 MAY',
#   'year': '2019',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2019 JUN',
#   'value': '264',
#   'label': '2019 JUN',
#   'year': '2019',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2019 JUL',
#   'value': '239',
#   'label': '2019 JUL',
#   'year': '2019',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2022-10-11T23:00:00.000Z'},
#  {'date': '2019 AUG',
#   'value': '242',
#   'label': '2019 AUG',
#   'year': '2019',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2019 SEP',
#   'value': '253',
#   'label': '2019 SEP',
#   'year': '2019',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2019 OCT',
#   'value': '324',
#   'label': '2019 OCT',
#   'year': '2019',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2019 NOV',
#   'value': '224',
#   'label': '2019 NOV',
#   'year': '2019',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2019 DEC',
#   'value': '238',
#   'label': '2019 DEC',
#   'year': '2019',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2020 JAN',
#   'value': '209',
#   'label': '2020 JAN',
#   'year': '2020',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2020 FEB',
#   'value': '234',
#   'label': '2020 FEB',
#   'year': '2020',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2020 MAR',
#   'value': '210',
#   'label': '2020 MAR',
#   'year': '2020',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2020 APR',
#   'value': '170',
#   'label': '2020 APR',
#   'year': '2020',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2020 MAY',
#   'value': '136',
#   'label': '2020 MAY',
#   'year': '2020',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2020 JUN',
#   'value': '163',
#   'label': '2020 JUN',
#   'year': '2020',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2020 JUL',
#   'value': '224',
#   'label': '2020 JUL',
#   'year': '2020',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2020 AUG',
#   'value': '201',
#   'label': '2020 AUG',
#   'year': '2020',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2020 SEP',
#   'value': '230',
#   'label': '2020 SEP',
#   'year': '2020',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2020 OCT',
#   'value': '223',
#   'label': '2020 OCT',
#   'year': '2020',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2020 NOV',
#   'value': '253',
#   'label': '2020 NOV',
#   'year': '2020',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2020 DEC',
#   'value': '242',
#   'label': '2020 DEC',
#   'year': '2020',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2021 JAN',
#   'value': '232',
#   'label': '2021 JAN',
#   'year': '2021',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z'},
#  {'date': '2021 FEB',
#   'value': '234',
#   'label': '2021 FEB',
#   'year': '2021',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2021 MAR',
#   'value': '242',
#   'label': '2021 MAR',
#   'year': '2021',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2021 APR',
#   'value': '216',
#   'label': '2021 APR',
#   'year': '2021',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2021 MAY',
#   'value': '208',
#   'label': '2021 MAY',
#   'year': '2021',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2021 JUN',
#   'value': '233',
#   'label': '2021 JUN',
#   'year': '2021',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2021 JUL',
#   'value': '200',
#   'label': '2021 JUL',
#   'year': '2021',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2021 AUG',
#   'value': '240',
#   'label': '2021 AUG',
#   'year': '2021',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2021 SEP',
#   'value': '339',
#   'label': '2021 SEP',
#   'year': '2021',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2021 OCT',
#   'value': '214',
#   'label': '2021 OCT',
#   'year': '2021',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2021 NOV',
#   'value': '305',
#   'label': '2021 NOV',
#   'year': '2021',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2021 DEC',
#   'value': '208',
#   'label': '2021 DEC',
#   'year': '2021',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2022 JAN',
#   'value': '233',
#   'label': '2022 JAN',
#   'year': '2022',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2022 FEB',
#   'value': '207',
#   'label': '2022 FEB',
#   'year': '2022',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2022 MAR',
#   'value': '226',
#   'label': '2022 MAR',
#   'year': '2022',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2022 APR',
#   'value': '228',
#   'label': '2022 APR',
#   'year': '2022',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2022 MAY',
#   'value': '339',
#   'label': '2022 MAY',
#   'year': '2022',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2022 JUN',
#   'value': '319',
#   'label': '2022 JUN',
#   'year': '2022',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2022 JUL',
#   'value': '365',
#   'label': '2022 JUL',
#   'year': '2022',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2022 AUG',
#   'value': '356',
#   'label': '2022 AUG',
#   'year': '2022',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2022 SEP',
#   'value': '318',
#   'label': '2022 SEP',
#   'year': '2022',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2022 OCT',
#   'value': '235',
#   'label': '2022 OCT',
#   'year': '2022',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2022 NOV',
#   'value': '289',
#   'label': '2022 NOV',
#   'year': '2022',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2022 DEC',
#   'value': '323',
#   'label': '2022 DEC',
#   'year': '2022',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2023 JAN',
#   'value': '269',
#   'label': '2023 JAN',
#   'year': '2023',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2023 FEB',
#   'value': '283',
#   'label': '2023 FEB',
#   'year': '2023',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2023 MAR',
#   'value': '281',
#   'label': '2023 MAR',
#   'year': '2023',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2023 APR',
#   'value': '292',
#   'label': '2023 APR',
#   'year': '2023',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2023 MAY',
#   'value': '330',
#   'label': '2023 MAY',
#   'year': '2023',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2023 JUN',
#   'value': '276',
#   'label': '2023 JUN',
#   'year': '2023',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2023 JUL',
#   'value': '268',
#   'label': '2023 JUL',
#   'year': '2023',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2023 AUG',
#   'value': '274',
#   'label': '2023 AUG',
#   'year': '2023',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2023 SEP',
#   'value': '206',
#   'label': '2023 SEP',
#   'year': '2023',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2023 OCT',
#   'value': '262',
#   'label': '2023 OCT',
#   'year': '2023',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2023 NOV',
#   'value': '312',
#   'label': '2023 NOV',
#   'year': '2023',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2023 DEC',
#   'value': '210',
#   'label': '2023 DEC',
#   'year': '2023',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2024 JAN',
#   'value': '280',
#   'label': '2024 JAN',
#   'year': '2024',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2024 FEB',
#   'value': '323',
#   'label': '2024 FEB',
#   'year': '2024',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2024 MAR',
#   'value': '247',
#   'label': '2024 MAR',
#   'year': '2024',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2024 APR',
#   'value': '320',
#   'label': '2024 APR',
#   'year': '2024',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2024 MAY',
#   'value': '267',
#   'label': '2024 MAY',
#   'year': '2024',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2024 JUN',
#   'value': '276',
#   'label': '2024 JUN',
#   'year': '2024',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2024 JUL',
#   'value': '302',
#   'label': '2024 JUL',
#   'year': '2024',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'},
#  {'date': '2024 AUG',
#   'value': '227',
#   'label': '2024 AUG',
#   'year': '2024',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z'}]

# %%
with open("Monthly_Imports_Portugal.json", "w") as file:
   json.dump(data["months"],file)

# %%
base_data = "https://raw.githubusercontent.com/OliverGriffiths287/OliverGriffiths287.github.io/refs/heads/main/Monthly_Imports_{}.json"

countries = ['Algeria', 'Ghana', 'Germany', 'Sweden', 'France', 'India', 'Brazil', 'Netherlands', 'Portugal']

for i in countries:
   datatoUse =  base_data.format(i)

req = requests.get("https://raw.githubusercontent.com/RDeconomist/RDeconomist.github.io/main/charts/library/chartLine0.json")

data = req.json()

# // Get out base spec (as above)
url = "https://raw.githubusercontent.com/RDeconomist/RDeconomist.github.io/main/charts/library/chartLine0.json"
base_spec = requests.get(url).json()

# // Now since all of our work is going to be on unemployment, we need to change the base spec:
base_spec['title']['text'] = "Monthly UK imports"
base_spec['encoding']['x']['field'] = 'date'
base_spec['encoding']['y']['field'] = 'value'
base_spec['data']['url'] = 'XYZ'

# // Print out our new Spec:
print(json.dumps(base_spec, indent=2))

for i in countries:
   dataToUse =  base_data.format(i)

   ## Now build the chart spec:
   base_spec['data']['url'] = dataToUse
   base_spec['title']['subtitle'] = i

  # /// Turn the spec into JSON
   specJSON = json.dumps(base_spec)

  # /// Turn the json into an Altair chart and display it:
   new_chart = alt.Chart.from_json(specJSON)
   new_chart.display()
# Out:
# {
#   "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
#   "data": {
#     "url": "XYZ"
#   },
#   "title": {
#     "text": "Monthly UK imports"
#   },
#   "width": 300,
#   "height": 300,
#   "mark": {
#     "type": "line",
#     "color": "red"
#   },
#   "encoding": {
#     "x": {
#       "field": "date",
#       "type": "temporal"
#     },
#     "y": {
#       "field": "value",
#       "type": "quantitative"
#     }
#   }
# }
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
