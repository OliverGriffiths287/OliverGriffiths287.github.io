# %% [markdown]
# <a href="https://colab.research.google.com/github/OliverGriffiths287/OliverGriffiths287.github.io/blob/main/Portfolio_API_Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
# %pip install altair
import altair as alt

### PREPARING OUR BASE SPEC
req = requests.get("https://raw.githubusercontent.com/RDeconomist/RDeconomist.github.io/main/charts/library/chartLine0.json")

data = req.json()

# // Get out base spec (as above)
url = "https://raw.githubusercontent.com/RDeconomist/RDeconomist.github.io/main/charts/library/chartLine0.json"
base_spec = requests.get(url).json()

# // Now since all of our work is going to be on unemployment, we need to change the base spec:
base_spec['title']['text'] = "UK imports"
base_spec['encoding']['x']['field'] = 'date'
base_spec['encoding']['y']['field'] = 'value'
base_spec['data']['url'] = 'years'

# // Print out our new Spec:
print(json.dumps(base_spec, indent=2))

### RUNNING OUR LOOP

# // Define our base url with the {} placeholder for the country code.
base_api = 'https://api.ons.gov.uk/timeseries/{}/dataset/MRET/data'

# // Create a list of countries we want to get data for:
codes = ['KO2O', 'KO3R', 'ENYS', 'CHND', 'ENYP', 'ERDV', 'FKMP', 'CHNX', 'CHOC']
countries = ['Algeria', 'Ghana', 'Germany', 'Sweden', 'France', 'India', 'Brazil', 'Netherlands', 'Portugal']


for i in codes:

  ## Build the api that we want to use:
  apiToUse = base_api.format(i)
  # print(apiToUse)

for i in countries:

  ## Now build the chart spec:
  base_spec['data']['url'] = apiToUse
  base_spec['title']['subtitle'] = i

  # /// Turn the spec into JSON
  specJSON = json.dumps(base_spec)

  # /// Turn the json into an Altair chart and display it:
  new_chart = alt.Chart.from_json(specJSON)
  new_chart.display()
# Out:
# Requirement already satisfied: altair in /usr/local/lib/python3.10/dist-packages (4.2.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair) (4.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from altair) (1.26.4)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.10/dist-packages (from altair) (2.2.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair) (0.12.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18->altair) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18->altair) (2024.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair) (3.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.18->altair) (1.16.0)
# {
#   "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
#   "data": {
#     "url": "years"
#   },
#   "title": {
#     "text": "UK imports"
#   },
#   "width": 300,
#   "height": 300,
#   "mark": {
#     "type": "line",
#     "color": "red"
#   },
#   "encoding": {
#     "x": {
#       "field": "date",
#       "type": "temporal"
#     },
#     "y": {
#       "field": "value",
#       "type": "quantitative"
#     }
#   }
# }
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)

# %%
import requests
import json

# %%
### RUNNING OUR LOOP

# // Define our base url with the {} placeholder for the country code.
base_api = 'https://api.ons.gov.uk/timeseries/{}/dataset/MRET/data'

# // Create a list of countries we want to get data for:
codes = ['KO2O', 'KO3R', 'ENYS', 'CHND', 'ENYP', 'ERDV', 'FKMP', 'CHNX', 'CHOC']
countries = ['Algeria', 'Ghana', 'Germany', 'Sweden', 'France', 'India', 'Brazil', 'Netherlands', 'Portugal']

# %%
response=requests.get(base_api.format("KO2O"))
data=response.json()
data.keys()
# Out:
# dict_keys(['description', 'months', 'quarters', 'relatedDatasets', 'relatedDocuments', 'sourceDatasets', 'type', 'uri', 'versions', 'years'])

# %%
data['months']
# Out:
# [{'date': '1997 JAN',
#   'label': '1997 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '0',
#   'year': '1997'},
#  {'date': '1997 FEB',
#   'label': '1997 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '17',
#   'year': '1997'},
#  {'date': '1997 MAR',
#   'label': '1997 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '10',
#   'year': '1997'},
#  {'date': '1997 APR',
#   'label': '1997 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '3',
#   'year': '1997'},
#  {'date': '1997 MAY',
#   'label': '1997 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '7',
#   'year': '1997'},
#  {'date': '1997 JUN',
#   'label': '1997 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '12',
#   'year': '1997'},
#  {'date': '1997 JUL',
#   'label': '1997 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '25',
#   'year': '1997'},
#  {'date': '1997 AUG',
#   'label': '1997 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '10',
#   'year': '1997'},
#  {'date': '1997 SEP',
#   'label': '1997 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '15',
#   'year': '1997'},
#  {'date': '1997 OCT',
#   'label': '1997 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '16',
#   'year': '1997'},
#  {'date': '1997 NOV',
#   'label': '1997 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '3',
#   'year': '1997'},
#  {'date': '1997 DEC',
#   'label': '1997 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '0',
#   'year': '1997'},
#  {'date': '1998 JAN',
#   'label': '1998 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '1',
#   'year': '1998'},
#  {'date': '1998 FEB',
#   'label': '1998 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '23',
#   'year': '1998'},
#  {'date': '1998 MAR',
#   'label': '1998 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '7',
#   'year': '1998'},
#  {'date': '1998 APR',
#   'label': '1998 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '6',
#   'year': '1998'},
#  {'date': '1998 MAY',
#   'label': '1998 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '1',
#   'year': '1998'},
#  {'date': '1998 JUN',
#   'label': '1998 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '10',
#   'year': '1998'},
#  {'date': '1998 JUL',
#   'label': '1998 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '14',
#   'year': '1998'},
#  {'date': '1998 AUG',
#   'label': '1998 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '5',
#   'year': '1998'},
#  {'date': '1998 SEP',
#   'label': '1998 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '6',
#   'year': '1998'},
#  {'date': '1998 OCT',
#   'label': '1998 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '9',
#   'year': '1998'},
#  {'date': '1998 NOV',
#   'label': '1998 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '21',
#   'year': '1998'},
#  {'date': '1998 DEC',
#   'label': '1998 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '10',
#   'year': '1998'},
#  {'date': '1999 JAN',
#   'label': '1999 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '19',
#   'year': '1999'},
#  {'date': '1999 FEB',
#   'label': '1999 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '9',
#   'year': '1999'},
#  {'date': '1999 MAR',
#   'label': '1999 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '4',
#   'year': '1999'},
#  {'date': '1999 APR',
#   'label': '1999 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '0',
#   'year': '1999'},
#  {'date': '1999 MAY',
#   'label': '1999 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '8',
#   'year': '1999'},
#  {'date': '1999 JUN',
#   'label': '1999 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '11',
#   'year': '1999'},
#  {'date': '1999 JUL',
#   'label': '1999 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '7',
#   'year': '1999'},
#  {'date': '1999 AUG',
#   'label': '1999 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '14',
#   'year': '1999'},
#  {'date': '1999 SEP',
#   'label': '1999 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '35',
#   'year': '1999'},
#  {'date': '1999 OCT',
#   'label': '1999 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '19',
#   'year': '1999'},
#  {'date': '1999 NOV',
#   'label': '1999 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '32',
#   'year': '1999'},
#  {'date': '1999 DEC',
#   'label': '1999 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '36',
#   'year': '1999'},
#  {'date': '2000 JAN',
#   'label': '2000 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '30',
#   'year': '2000'},
#  {'date': '2000 FEB',
#   'label': '2000 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '39',
#   'year': '2000'},
#  {'date': '2000 MAR',
#   'label': '2000 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '47',
#   'year': '2000'},
#  {'date': '2000 APR',
#   'label': '2000 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '55',
#   'year': '2000'},
#  {'date': '2000 MAY',
#   'label': '2000 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '42',
#   'year': '2000'},
#  {'date': '2000 JUN',
#   'label': '2000 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '42',
#   'year': '2000'},
#  {'date': '2000 JUL',
#   'label': '2000 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '43',
#   'year': '2000'},
#  {'date': '2000 AUG',
#   'label': '2000 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '37',
#   'year': '2000'},
#  {'date': '2000 SEP',
#   'label': '2000 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '60',
#   'year': '2000'},
#  {'date': '2000 OCT',
#   'label': '2000 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '51',
#   'year': '2000'},
#  {'date': '2000 NOV',
#   'label': '2000 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '48',
#   'year': '2000'},
#  {'date': '2000 DEC',
#   'label': '2000 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '48',
#   'year': '2000'},
#  {'date': '2001 JAN',
#   'label': '2001 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '15',
#   'year': '2001'},
#  {'date': '2001 FEB',
#   'label': '2001 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '37',
#   'year': '2001'},
#  {'date': '2001 MAR',
#   'label': '2001 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '28',
#   'year': '2001'},
#  {'date': '2001 APR',
#   'label': '2001 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '22',
#   'year': '2001'},
#  {'date': '2001 MAY',
#   'label': '2001 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '34',
#   'year': '2001'},
#  {'date': '2001 JUN',
#   'label': '2001 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '3',
#   'year': '2001'},
#  {'date': '2001 JUL',
#   'label': '2001 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '15',
#   'year': '2001'},
#  {'date': '2001 AUG',
#   'label': '2001 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '0',
#   'year': '2001'},
#  {'date': '2001 SEP',
#   'label': '2001 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '14',
#   'year': '2001'},
#  {'date': '2001 OCT',
#   'label': '2001 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '41',
#   'year': '2001'},
#  {'date': '2001 NOV',
#   'label': '2001 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '36',
#   'year': '2001'},
#  {'date': '2001 DEC',
#   'label': '2001 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '11',
#   'year': '2001'},
#  {'date': '2002 JAN',
#   'label': '2002 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '1',
#   'year': '2002'},
#  {'date': '2002 FEB',
#   'label': '2002 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '11',
#   'year': '2002'},
#  {'date': '2002 MAR',
#   'label': '2002 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '41',
#   'year': '2002'},
#  {'date': '2002 APR',
#   'label': '2002 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '25',
#   'year': '2002'},
#  {'date': '2002 MAY',
#   'label': '2002 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '36',
#   'year': '2002'},
#  {'date': '2002 JUN',
#   'label': '2002 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '31',
#   'year': '2002'},
#  {'date': '2002 JUL',
#   'label': '2002 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '75',
#   'year': '2002'},
#  {'date': '2002 AUG',
#   'label': '2002 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '21',
#   'year': '2002'},
#  {'date': '2002 SEP',
#   'label': '2002 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '44',
#   'year': '2002'},
#  {'date': '2002 OCT',
#   'label': '2002 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '48',
#   'year': '2002'},
#  {'date': '2002 NOV',
#   'label': '2002 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '44',
#   'year': '2002'},
#  {'date': '2002 DEC',
#   'label': '2002 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '13',
#   'year': '2002'},
#  {'date': '2003 JAN',
#   'label': '2003 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '1',
#   'year': '2003'},
#  {'date': '2003 FEB',
#   'label': '2003 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '23',
#   'year': '2003'},
#  {'date': '2003 MAR',
#   'label': '2003 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '19',
#   'year': '2003'},
#  {'date': '2003 APR',
#   'label': '2003 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '1',
#   'year': '2003'},
#  {'date': '2003 MAY',
#   'label': '2003 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '16',
#   'year': '2003'},
#  {'date': '2003 JUN',
#   'label': '2003 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '26',
#   'year': '2003'},
#  {'date': '2003 JUL',
#   'label': '2003 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '34',
#   'year': '2003'},
#  {'date': '2003 AUG',
#   'label': '2003 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '36',
#   'year': '2003'},
#  {'date': '2003 SEP',
#   'label': '2003 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '59',
#   'year': '2003'},
#  {'date': '2003 OCT',
#   'label': '2003 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '34',
#   'year': '2003'},
#  {'date': '2003 NOV',
#   'label': '2003 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '31',
#   'year': '2003'},
#  {'date': '2003 DEC',
#   'label': '2003 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '12',
#   'year': '2003'},
#  {'date': '2004 JAN',
#   'label': '2004 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '61',
#   'year': '2004'},
#  {'date': '2004 FEB',
#   'label': '2004 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '45',
#   'year': '2004'},
#  {'date': '2004 MAR',
#   'label': '2004 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '14',
#   'year': '2004'},
#  {'date': '2004 APR',
#   'label': '2004 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '33',
#   'year': '2004'},
#  {'date': '2004 MAY',
#   'label': '2004 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '41',
#   'year': '2004'},
#  {'date': '2004 JUN',
#   'label': '2004 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '45',
#   'year': '2004'},
#  {'date': '2004 JUL',
#   'label': '2004 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '49',
#   'year': '2004'},
#  {'date': '2004 AUG',
#   'label': '2004 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '9',
#   'year': '2004'},
#  {'date': '2004 SEP',
#   'label': '2004 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '81',
#   'year': '2004'},
#  {'date': '2004 OCT',
#   'label': '2004 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '9',
#   'year': '2004'},
#  {'date': '2004 NOV',
#   'label': '2004 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '15',
#   'year': '2004'},
#  {'date': '2004 DEC',
#   'label': '2004 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '21',
#   'year': '2004'},
#  {'date': '2005 JAN',
#   'label': '2005 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '27',
#   'year': '2005'},
#  {'date': '2005 FEB',
#   'label': '2005 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '13',
#   'year': '2005'},
#  {'date': '2005 MAR',
#   'label': '2005 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '5',
#   'year': '2005'},
#  {'date': '2005 APR',
#   'label': '2005 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '2',
#   'year': '2005'},
#  {'date': '2005 MAY',
#   'label': '2005 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '21',
#   'year': '2005'},
#  {'date': '2005 JUN',
#   'label': '2005 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '68',
#   'year': '2005'},
#  {'date': '2005 JUL',
#   'label': '2005 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '60',
#   'year': '2005'},
#  {'date': '2005 AUG',
#   'label': '2005 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '49',
#   'year': '2005'},
#  {'date': '2005 SEP',
#   'label': '2005 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '52',
#   'year': '2005'},
#  {'date': '2005 OCT',
#   'label': '2005 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '78',
#   'year': '2005'},
#  {'date': '2005 NOV',
#   'label': '2005 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '54',
#   'year': '2005'},
#  {'date': '2005 DEC',
#   'label': '2005 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '55',
#   'year': '2005'},
#  {'date': '2006 JAN',
#   'label': '2006 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '106',
#   'year': '2006'},
#  {'date': '2006 FEB',
#   'label': '2006 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '129',
#   'year': '2006'},
#  {'date': '2006 MAR',
#   'label': '2006 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '101',
#   'year': '2006'},
#  {'date': '2006 APR',
#   'label': '2006 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '50',
#   'year': '2006'},
#  {'date': '2006 MAY',
#   'label': '2006 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '24',
#   'year': '2006'},
#  {'date': '2006 JUN',
#   'label': '2006 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '119',
#   'year': '2006'},
#  {'date': '2006 JUL',
#   'label': '2006 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '28',
#   'year': '2006'},
#  {'date': '2006 AUG',
#   'label': '2006 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '73',
#   'year': '2006'},
#  {'date': '2006 SEP',
#   'label': '2006 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z',
#   'value': '129',
#   'year': '2006'},
#  {'date': '2006 OCT',
#   'label': '2006 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '57',
#   'year': '2006'},
#  {'date': '2006 NOV',
#   'label': '2006 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '116',
#   'year': '2006'},
#  {'date': '2006 DEC',
#   'label': '2006 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '21',
#   'year': '2006'},
#  {'date': '2007 JAN',
#   'label': '2007 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '44',
#   'year': '2007'},
#  {'date': '2007 FEB',
#   'label': '2007 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '19',
#   'year': '2007'},
#  {'date': '2007 MAR',
#   'label': '2007 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '22',
#   'year': '2007'},
#  {'date': '2007 APR',
#   'label': '2007 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '106',
#   'year': '2007'},
#  {'date': '2007 MAY',
#   'label': '2007 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '40',
#   'year': '2007'},
#  {'date': '2007 JUN',
#   'label': '2007 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '47',
#   'year': '2007'},
#  {'date': '2007 JUL',
#   'label': '2007 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '88',
#   'year': '2007'},
#  {'date': '2007 AUG',
#   'label': '2007 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '195',
#   'year': '2007'},
#  {'date': '2007 SEP',
#   'label': '2007 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '161',
#   'year': '2007'},
#  {'date': '2007 OCT',
#   'label': '2007 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '36',
#   'year': '2007'},
#  {'date': '2007 NOV',
#   'label': '2007 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '142',
#   'year': '2007'},
#  {'date': '2007 DEC',
#   'label': '2007 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '10',
#   'year': '2007'},
#  {'date': '2008 JAN',
#   'label': '2008 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '34',
#   'year': '2008'},
#  {'date': '2008 FEB',
#   'label': '2008 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '115',
#   'year': '2008'},
#  {'date': '2008 MAR',
#   'label': '2008 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '31',
#   'year': '2008'},
#  {'date': '2008 APR',
#   'label': '2008 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '1',
#   'year': '2008'},
#  {'date': '2008 MAY',
#   'label': '2008 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '74',
#   'year': '2008'},
#  {'date': '2008 JUN',
#   'label': '2008 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '204',
#   'year': '2008'},
#  {'date': '2008 JUL',
#   'label': '2008 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '173',
#   'year': '2008'},
#  {'date': '2008 AUG',
#   'label': '2008 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '114',
#   'year': '2008'},
#  {'date': '2008 SEP',
#   'label': '2008 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '29',
#   'year': '2008'},
#  {'date': '2008 OCT',
#   'label': '2008 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '1',
#   'year': '2008'},
#  {'date': '2008 NOV',
#   'label': '2008 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '51',
#   'year': '2008'},
#  {'date': '2008 DEC',
#   'label': '2008 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '43',
#   'year': '2008'},
#  {'date': '2009 JAN',
#   'label': '2009 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '109',
#   'year': '2009'},
#  {'date': '2009 FEB',
#   'label': '2009 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '71',
#   'year': '2009'},
#  {'date': '2009 MAR',
#   'label': '2009 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '107',
#   'year': '2009'},
#  {'date': '2009 APR',
#   'label': '2009 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '32',
#   'year': '2009'},
#  {'date': '2009 MAY',
#   'label': '2009 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '68',
#   'year': '2009'},
#  {'date': '2009 JUN',
#   'label': '2009 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '31',
#   'year': '2009'},
#  {'date': '2009 JUL',
#   'label': '2009 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '17',
#   'year': '2009'},
#  {'date': '2009 AUG',
#   'label': '2009 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '41',
#   'year': '2009'},
#  {'date': '2009 SEP',
#   'label': '2009 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '18',
#   'year': '2009'},
#  {'date': '2009 OCT',
#   'label': '2009 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '14',
#   'year': '2009'},
#  {'date': '2009 NOV',
#   'label': '2009 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '24',
#   'year': '2009'},
#  {'date': '2009 DEC',
#   'label': '2009 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '19',
#   'year': '2009'},
#  {'date': '2010 JAN',
#   'label': '2010 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '18',
#   'year': '2010'},
#  {'date': '2010 FEB',
#   'label': '2010 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '13',
#   'year': '2010'},
#  {'date': '2010 MAR',
#   'label': '2010 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '132',
#   'year': '2010'},
#  {'date': '2010 APR',
#   'label': '2010 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '95',
#   'year': '2010'},
#  {'date': '2010 MAY',
#   'label': '2010 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '116',
#   'year': '2010'},
#  {'date': '2010 JUN',
#   'label': '2010 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '44',
#   'year': '2010'},
#  {'date': '2010 JUL',
#   'label': '2010 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '1',
#   'year': '2010'},
#  {'date': '2010 AUG',
#   'label': '2010 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '152',
#   'year': '2010'},
#  {'date': '2010 SEP',
#   'label': '2010 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '21',
#   'year': '2010'},
#  {'date': '2010 OCT',
#   'label': '2010 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '1',
#   'year': '2010'},
#  {'date': '2010 NOV',
#   'label': '2010 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '72',
#   'year': '2010'},
#  {'date': '2010 DEC',
#   'label': '2010 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '39',
#   'year': '2010'},
#  {'date': '2011 JAN',
#   'label': '2011 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '123',
#   'year': '2011'},
#  {'date': '2011 FEB',
#   'label': '2011 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '94',
#   'year': '2011'},
#  {'date': '2011 MAR',
#   'label': '2011 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '3',
#   'year': '2011'},
#  {'date': '2011 APR',
#   'label': '2011 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '22',
#   'year': '2011'},
#  {'date': '2011 MAY',
#   'label': '2011 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '46',
#   'year': '2011'},
#  {'date': '2011 JUN',
#   'label': '2011 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '167',
#   'year': '2011'},
#  {'date': '2011 JUL',
#   'label': '2011 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '108',
#   'year': '2011'},
#  {'date': '2011 AUG',
#   'label': '2011 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '153',
#   'year': '2011'},
#  {'date': '2011 SEP',
#   'label': '2011 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '96',
#   'year': '2011'},
#  {'date': '2011 OCT',
#   'label': '2011 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '218',
#   'year': '2011'},
#  {'date': '2011 NOV',
#   'label': '2011 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '291',
#   'year': '2011'},
#  {'date': '2011 DEC',
#   'label': '2011 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '208',
#   'year': '2011'},
#  {'date': '2012 JAN',
#   'label': '2012 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '135',
#   'year': '2012'},
#  {'date': '2012 FEB',
#   'label': '2012 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '102',
#   'year': '2012'},
#  {'date': '2012 MAR',
#   'label': '2012 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '256',
#   'year': '2012'},
#  {'date': '2012 APR',
#   'label': '2012 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '163',
#   'year': '2012'},
#  {'date': '2012 MAY',
#   'label': '2012 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '151',
#   'year': '2012'},
#  {'date': '2012 JUN',
#   'label': '2012 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '249',
#   'year': '2012'},
#  {'date': '2012 JUL',
#   'label': '2012 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '290',
#   'year': '2012'},
#  {'date': '2012 AUG',
#   'label': '2012 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '201',
#   'year': '2012'},
#  {'date': '2012 SEP',
#   'label': '2012 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '44',
#   'year': '2012'},
#  {'date': '2012 OCT',
#   'label': '2012 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '43',
#   'year': '2012'},
#  {'date': '2012 NOV',
#   'label': '2012 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '173',
#   'year': '2012'},
#  {'date': '2012 DEC',
#   'label': '2012 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '279',
#   'year': '2012'},
#  {'date': '2013 JAN',
#   'label': '2013 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '364',
#   'year': '2013'},
#  {'date': '2013 FEB',
#   'label': '2013 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '428',
#   'year': '2013'},
#  {'date': '2013 MAR',
#   'label': '2013 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '332',
#   'year': '2013'},
#  {'date': '2013 APR',
#   'label': '2013 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '469',
#   'year': '2013'},
#  {'date': '2013 MAY',
#   'label': '2013 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '143',
#   'year': '2013'},
#  {'date': '2013 JUN',
#   'label': '2013 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '125',
#   'year': '2013'},
#  {'date': '2013 JUL',
#   'label': '2013 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '387',
#   'year': '2013'},
#  {'date': '2013 AUG',
#   'label': '2013 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '166',
#   'year': '2013'},
#  {'date': '2013 SEP',
#   'label': '2013 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '327',
#   'year': '2013'},
#  {'date': '2013 OCT',
#   'label': '2013 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '236',
#   'year': '2013'},
#  {'date': '2013 NOV',
#   'label': '2013 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '141',
#   'year': '2013'},
#  {'date': '2013 DEC',
#   'label': '2013 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '235',
#   'year': '2013'},
#  {'date': '2014 JAN',
#   'label': '2014 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '346',
#   'year': '2014'},
#  {'date': '2014 FEB',
#   'label': '2014 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '266',
#   'year': '2014'},
#  {'date': '2014 MAR',
#   'label': '2014 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '211',
#   'year': '2014'},
#  {'date': '2014 APR',
#   'label': '2014 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '136',
#   'year': '2014'},
#  {'date': '2014 MAY',
#   'label': '2014 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '396',
#   'year': '2014'},
#  {'date': '2014 JUN',
#   'label': '2014 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '363',
#   'year': '2014'},
#  {'date': '2014 JUL',
#   'label': '2014 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z',
#   'value': '369',
#   'year': '2014'},
#  {'date': '2014 AUG',
#   'label': '2014 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '297',
#   'year': '2014'},
#  {'date': '2014 SEP',
#   'label': '2014 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '323',
#   'year': '2014'},
#  {'date': '2014 OCT',
#   'label': '2014 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '271',
#   'year': '2014'},
#  {'date': '2014 NOV',
#   'label': '2014 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '241',
#   'year': '2014'},
#  {'date': '2014 DEC',
#   'label': '2014 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '198',
#   'year': '2014'},
#  {'date': '2015 JAN',
#   'label': '2015 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '182',
#   'year': '2015'},
#  {'date': '2015 FEB',
#   'label': '2015 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '212',
#   'year': '2015'},
#  {'date': '2015 MAR',
#   'label': '2015 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '272',
#   'year': '2015'},
#  {'date': '2015 APR',
#   'label': '2015 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '129',
#   'year': '2015'},
#  {'date': '2015 MAY',
#   'label': '2015 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '171',
#   'year': '2015'},
#  {'date': '2015 JUN',
#   'label': '2015 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '192',
#   'year': '2015'},
#  {'date': '2015 JUL',
#   'label': '2015 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '162',
#   'year': '2015'},
#  {'date': '2015 AUG',
#   'label': '2015 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '108',
#   'year': '2015'},
#  {'date': '2015 SEP',
#   'label': '2015 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '127',
#   'year': '2015'},
#  {'date': '2015 OCT',
#   'label': '2015 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '81',
#   'year': '2015'},
#  {'date': '2015 NOV',
#   'label': '2015 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '88',
#   'year': '2015'},
#  {'date': '2015 DEC',
#   'label': '2015 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '105',
#   'year': '2015'},
#  {'date': '2016 JAN',
#   'label': '2016 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '47',
#   'year': '2016'},
#  {'date': '2016 FEB',
#   'label': '2016 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '41',
#   'year': '2016'},
#  {'date': '2016 MAR',
#   'label': '2016 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '59',
#   'year': '2016'},
#  {'date': '2016 APR',
#   'label': '2016 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '48',
#   'year': '2016'},
#  {'date': '2016 MAY',
#   'label': '2016 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '9',
#   'year': '2016'},
#  {'date': '2016 JUN',
#   'label': '2016 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '15',
#   'year': '2016'},
#  {'date': '2016 JUL',
#   'label': '2016 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '88',
#   'year': '2016'},
#  {'date': '2016 AUG',
#   'label': '2016 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '118',
#   'year': '2016'},
#  {'date': '2016 SEP',
#   'label': '2016 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '66',
#   'year': '2016'},
#  {'date': '2016 OCT',
#   'label': '2016 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '79',
#   'year': '2016'},
#  {'date': '2016 NOV',
#   'label': '2016 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '26',
#   'year': '2016'},
#  {'date': '2016 DEC',
#   'label': '2016 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '97',
#   'year': '2016'},
#  {'date': '2017 JAN',
#   'label': '2017 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '15',
#   'year': '2017'},
#  {'date': '2017 FEB',
#   'label': '2017 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '10',
#   'year': '2017'},
#  {'date': '2017 MAR',
#   'label': '2017 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '208',
#   'year': '2017'},
#  {'date': '2017 APR',
#   'label': '2017 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '189',
#   'year': '2017'},
#  {'date': '2017 MAY',
#   'label': '2017 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '130',
#   'year': '2017'},
#  {'date': '2017 JUN',
#   'label': '2017 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '197',
#   'year': '2017'},
#  {'date': '2017 JUL',
#   'label': '2017 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '75',
#   'year': '2017'},
#  {'date': '2017 AUG',
#   'label': '2017 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '78',
#   'year': '2017'},
#  {'date': '2017 SEP',
#   'label': '2017 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '82',
#   'year': '2017'},
#  {'date': '2017 OCT',
#   'label': '2017 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '153',
#   'year': '2017'},
#  {'date': '2017 NOV',
#   'label': '2017 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z',
#   'value': '224',
#   'year': '2017'},
#  {'date': '2017 DEC',
#   'label': '2017 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '42',
#   'year': '2017'},
#  {'date': '2018 JAN',
#   'label': '2018 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '131',
#   'year': '2018'},
#  {'date': '2018 FEB',
#   'label': '2018 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '120',
#   'year': '2018'},
#  {'date': '2018 MAR',
#   'label': '2018 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '82',
#   'year': '2018'},
#  {'date': '2018 APR',
#   'label': '2018 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '117',
#   'year': '2018'},
#  {'date': '2018 MAY',
#   'label': '2018 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '160',
#   'year': '2018'},
#  {'date': '2018 JUN',
#   'label': '2018 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '141',
#   'year': '2018'},
#  {'date': '2018 JUL',
#   'label': '2018 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z',
#   'value': '371',
#   'year': '2018'},
#  {'date': '2018 AUG',
#   'label': '2018 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '276',
#   'year': '2018'},
#  {'date': '2018 SEP',
#   'label': '2018 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '144',
#   'year': '2018'},
#  {'date': '2018 OCT',
#   'label': '2018 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '108',
#   'year': '2018'},
#  {'date': '2018 NOV',
#   'label': '2018 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '411',
#   'year': '2018'},
#  {'date': '2018 DEC',
#   'label': '2018 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '178',
#   'year': '2018'},
#  {'date': '2019 JAN',
#   'label': '2019 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '302',
#   'year': '2019'},
#  {'date': '2019 FEB',
#   'label': '2019 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '60',
#   'year': '2019'},
#  {'date': '2019 MAR',
#   'label': '2019 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '224',
#   'year': '2019'},
#  {'date': '2019 APR',
#   'label': '2019 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '146',
#   'year': '2019'},
#  {'date': '2019 MAY',
#   'label': '2019 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z',
#   'value': '248',
#   'year': '2019'},
#  {'date': '2019 JUN',
#   'label': '2019 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z',
#   'value': '217',
#   'year': '2019'},
#  {'date': '2019 JUL',
#   'label': '2019 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z',
#   'value': '175',
#   'year': '2019'},
#  {'date': '2019 AUG',
#   'label': '2019 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '47',
#   'year': '2019'},
#  {'date': '2019 SEP',
#   'label': '2019 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '221',
#   'year': '2019'},
#  {'date': '2019 OCT',
#   'label': '2019 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '260',
#   'year': '2019'},
#  {'date': '2019 NOV',
#   'label': '2019 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '53',
#   'year': '2019'},
#  {'date': '2019 DEC',
#   'label': '2019 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z',
#   'value': '78',
#   'year': '2019'},
#  {'date': '2020 JAN',
#   'label': '2020 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '48',
#   'year': '2020'},
#  {'date': '2020 FEB',
#   'label': '2020 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '134',
#   'year': '2020'},
#  {'date': '2020 MAR',
#   'label': '2020 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z',
#   'value': '100',
#   'year': '2020'},
#  {'date': '2020 APR',
#   'label': '2020 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '2',
#   'year': '2020'},
#  {'date': '2020 MAY',
#   'label': '2020 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z',
#   'value': '35',
#   'year': '2020'},
#  {'date': '2020 JUN',
#   'label': '2020 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '27',
#   'year': '2020'},
#  {'date': '2020 JUL',
#   'label': '2020 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '25',
#   'year': '2020'},
#  {'date': '2020 AUG',
#   'label': '2020 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '23',
#   'year': '2020'},
#  {'date': '2020 SEP',
#   'label': '2020 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '5',
#   'year': '2020'},
#  {'date': '2020 OCT',
#   'label': '2020 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '1',
#   'year': '2020'},
#  {'date': '2020 NOV',
#   'label': '2020 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '41',
#   'year': '2020'},
#  {'date': '2020 DEC',
#   'label': '2020 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '44',
#   'year': '2020'},
#  {'date': '2021 JAN',
#   'label': '2021 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z',
#   'value': '38',
#   'year': '2021'},
#  {'date': '2021 FEB',
#   'label': '2021 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '1',
#   'year': '2021'},
#  {'date': '2021 MAR',
#   'label': '2021 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '32',
#   'year': '2021'},
#  {'date': '2021 APR',
#   'label': '2021 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '30',
#   'year': '2021'},
#  {'date': '2021 MAY',
#   'label': '2021 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z',
#   'value': '49',
#   'year': '2021'},
#  {'date': '2021 JUN',
#   'label': '2021 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '125',
#   'year': '2021'},
#  {'date': '2021 JUL',
#   'label': '2021 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z',
#   'value': '63',
#   'year': '2021'},
#  {'date': '2021 AUG',
#   'label': '2021 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '15',
#   'year': '2021'},
#  {'date': '2021 SEP',
#   'label': '2021 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '78',
#   'year': '2021'},
#  {'date': '2021 OCT',
#   'label': '2021 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '270',
#   'year': '2021'},
#  {'date': '2021 NOV',
#   'label': '2021 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '75',
#   'year': '2021'},
#  {'date': '2021 DEC',
#   'label': '2021 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z',
#   'value': '301',
#   'year': '2021'},
#  {'date': '2022 JAN',
#   'label': '2022 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-02-10T00:00:00.000Z',
#   'value': '150',
#   'year': '2022'},
#  {'date': '2022 FEB',
#   'label': '2022 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-02-10T00:00:00.000Z',
#   'value': '203',
#   'year': '2022'},
#  {'date': '2022 MAR',
#   'label': '2022 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z',
#   'value': '133',
#   'year': '2022'},
#  {'date': '2022 APR',
#   'label': '2022 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-02-10T00:00:00.000Z',
#   'value': '470',
#   'year': '2022'},
#  {'date': '2022 MAY',
#   'label': '2022 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '142',
#   'year': '2022'},
#  {'date': '2022 JUN',
#   'label': '2022 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '39',
#   'year': '2022'},
#  {'date': '2022 JUL',
#   'label': '2022 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '46',
#   'year': '2022'},
#  {'date': '2022 AUG',
#   'label': '2022 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-02-10T00:00:00.000Z',
#   'value': '67',
#   'year': '2022'},
#  {'date': '2022 SEP',
#   'label': '2022 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-02-10T00:00:00.000Z',
#   'value': '176',
#   'year': '2022'},
#  {'date': '2022 OCT',
#   'label': '2022 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '156',
#   'year': '2022'},
#  {'date': '2022 NOV',
#   'label': '2022 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-01-13T00:00:00.000Z',
#   'value': '21',
#   'year': '2022'},
#  {'date': '2022 DEC',
#   'label': '2022 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-02-10T00:00:00.000Z',
#   'value': '235',
#   'year': '2022'},
#  {'date': '2023 JAN',
#   'label': '2023 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-01-12T00:00:00.000Z',
#   'value': '187',
#   'year': '2023'},
#  {'date': '2023 FEB',
#   'label': '2023 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-04-12T23:00:00.000Z',
#   'value': '186',
#   'year': '2023'},
#  {'date': '2023 MAR',
#   'label': '2023 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-05-11T23:00:00.000Z',
#   'value': '138',
#   'year': '2023'},
#  {'date': '2023 APR',
#   'label': '2023 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-06-13T23:00:00.000Z',
#   'value': '16',
#   'year': '2023'},
#  {'date': '2023 MAY',
#   'label': '2023 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-08-10T23:00:00.000Z',
#   'value': '220',
#   'year': '2023'},
#  {'date': '2023 JUN',
#   'label': '2023 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-08-10T23:00:00.000Z',
#   'value': '57',
#   'year': '2023'},
#  {'date': '2023 JUL',
#   'label': '2023 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-09-12T23:00:00.000Z',
#   'value': '47',
#   'year': '2023'},
#  {'date': '2023 AUG',
#   'label': '2023 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-10-11T23:00:00.000Z',
#   'value': '145',
#   'year': '2023'},
#  {'date': '2023 SEP',
#   'label': '2023 SEP',
#   'month': 'September',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-02-15T00:00:00.000Z',
#   'value': '277',
#   'year': '2023'},
#  {'date': '2023 OCT',
#   'label': '2023 OCT',
#   'month': 'October',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2023-12-13T00:00:00.000Z',
#   'value': '100',
#   'year': '2023'},
#  {'date': '2023 NOV',
#   'label': '2023 NOV',
#   'month': 'November',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z',
#   'value': '128',
#   'year': '2023'},
#  {'date': '2023 DEC',
#   'label': '2023 DEC',
#   'month': 'December',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-02-15T00:00:00.000Z',
#   'value': '163',
#   'year': '2023'},
#  {'date': '2024 JAN',
#   'label': '2024 JAN',
#   'month': 'January',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-07-10T23:00:00.000Z',
#   'value': '111',
#   'year': '2024'},
#  {'date': '2024 FEB',
#   'label': '2024 FEB',
#   'month': 'February',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-04-11T23:00:00.000Z',
#   'value': '35',
#   'year': '2024'},
#  {'date': '2024 MAR',
#   'label': '2024 MAR',
#   'month': 'March',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z',
#   'value': '90',
#   'year': '2024'},
#  {'date': '2024 APR',
#   'label': '2024 APR',
#   'month': 'April',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z',
#   'value': '118',
#   'year': '2024'},
#  {'date': '2024 MAY',
#   'label': '2024 MAY',
#   'month': 'May',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-07-10T23:00:00.000Z',
#   'value': '194',
#   'year': '2024'},
#  {'date': '2024 JUN',
#   'label': '2024 JUN',
#   'month': 'June',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-08-14T23:00:00.000Z',
#   'value': '190',
#   'year': '2024'},
#  {'date': '2024 JUL',
#   'label': '2024 JUL',
#   'month': 'July',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-09-10T23:00:00.000Z',
#   'value': '154',
#   'year': '2024'},
#  {'date': '2024 AUG',
#   'label': '2024 AUG',
#   'month': 'August',
#   'quarter': '',
#   'sourceDataset': 'MRET',
#   'updateDate': '2024-10-10T23:00:00.000Z',
#   'value': '31',
#   'year': '2024'}]

# %%
with open(".json", "w") as file:
  json.dump(data["months"],file)

# %%
code = "K020"
with open(f”trade_data_{code}.json”, “w”) as file:
