# %% [markdown]
# <a href="https://colab.research.google.com/github/OliverGriffiths287/OliverGriffiths287.github.io/blob/main/prices_takeaway_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import csv

with open('/content/prices_takeaways.csv', 'r') as file:
    reader = csv.reader(file)
    data = list(reader)

df = pd.DataFrame(data[1:], columns=data[0])
df = df[df['item_id'] == '220319']#
df.loc[df['region'] == '2', 'region'] = 'London'
df.loc[df['region'] == '3', 'region'] = 'South East'
df.loc[df['region'] == '4', 'region'] = 'South West'
df.loc[df['region'] == '5', 'region'] = 'East Anglia'
df.loc[df['region'] == '6', 'region'] = 'East Midlands'
df.loc[df['region'] == '7', 'region'] = 'West Midlands'
df.loc[df['region'] == '8', 'region'] = 'Yorkshire & Humber'
df.loc[df['region'] == '9', 'region'] = 'North West'
df.loc[df['region'] == '10', 'region'] = 'North'
df.loc[df['region'] == '11', 'region'] = 'Wales'
df.loc[df['region'] == '12', 'region'] = 'Scotland'
df.loc[df['region'] == '13', 'region'] = 'Northern Ireland'
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['quote_date'] = pd.to_datetime(df['quote_date'], format= '%Y%m').dt.strftime('%Y-%m')
df = df.rename(columns={'quote_date': 'month'})

print(df.dtypes)

df
# Out:
# month       object
# region      object
# price      float64
# item_id     object
# dtype: object
#           month         region  price item_id
# 171881  2002-02     South West    4.8  220319
# 171882  2002-02          Wales    4.4  220319
# 171883  2002-02  West Midlands    4.5  220319
# 171884  2002-02     South West    4.2  220319
# 171885  2002-02         London    2.9  220319
# ...         ...            ...    ...     ...
# 206724  2024-09     South West    7.1  220319
# 206725  2024-09         London    8.0  220319
# 206726  2024-09     North West    6.0  220319
# 206727  2024-09     North West    9.3  220319
# 206728  2024-09     South East    7.3  220319
#
# [34848 rows x 4 columns]

# %%
dfLondon = df.loc[df['region'] == 'London']
London_average = dfLondon.groupby('month')['price'].mean()
London_average = London_average.to_frame()
London_average = London_average.reset_index()
London_average['area'] = 'London'

London_average
# Out:
#        month     price    area
# 0    2002-02  4.162500  London
# 1    2002-03  4.765385  London
# 2    2002-04  4.714286  London
# 3    2002-05  4.166667  London
# 4    2002-06  4.180000  London
# ..       ...       ...     ...
# 267  2024-05  9.066111  London
# 268  2024-06  9.105000  London
# 269  2024-07  9.132778  London
# 270  2024-08  8.799412  London
# 271  2024-09  9.399412  London
#
# [272 rows x 3 columns]

# %%
dfSE = df.loc[df['region'] == 'South East']
SE_average = dfSE.groupby('month')['price'].mean()
SE_average = SE_average.to_frame()
SE_average = SE_average.reset_index()
SE_average['area'] = 'South East'

SE_average
# Out:
#        month     price        area
# 0    2002-02  4.202778  South East
# 1    2002-03  4.202778  South East
# 2    2002-04  4.255263  South East
# 3    2002-05  4.287500  South East
# 4    2002-06  4.181579  South East
# ..       ...       ...         ...
# 267  2024-05  7.195000  South East
# 268  2024-06  7.226818  South East
# 269  2024-07  7.213810  South East
# 270  2024-08  7.285909  South East
# 271  2024-09  7.485238  South East
#
# [272 rows x 3 columns]

# %%
dfSW = df.loc[df['region'] == 'South West']
SW_average = dfSW.groupby('month')['price'].mean()
SW_average = SW_average.to_frame()
SW_average = SW_average.reset_index()
SW_average['area'] = 'South West'

SW_average
# Out:
#        month     price        area
# 0    2002-02  4.663333  South West
# 1    2002-03  4.471667  South West
# 2    2002-04  4.471667  South West
# 3    2002-05  4.471667  South West
# 4    2002-06  4.471667  South West
# ..       ...       ...         ...
# 267  2024-05  7.166667  South West
# 268  2024-06  7.272727  South West
# 269  2024-07  7.300000  South West
# 270  2024-08  7.355556  South West
# 271  2024-09  7.340000  South West
#
# [272 rows x 3 columns]

# %%
dfEA = df.loc[df['region'] == 'East Anglia']
EA_average = dfEA.groupby('month')['price'].mean()
EA_average = EA_average.to_frame()
EA_average = EA_average.reset_index()
EA_average['area'] = 'East Anglia'

EA_average
# Out:
#        month     price         area
# 0    2002-02  4.276923  East Anglia
# 1    2002-03  4.284615  East Anglia
# 2    2002-04  4.259091  East Anglia
# 3    2002-05  4.259091  East Anglia
# 4    2002-06  4.340000  East Anglia
# ..       ...       ...          ...
# 267  2024-05  7.661111  East Anglia
# 268  2024-06  7.716667  East Anglia
# 269  2024-07  7.756250  East Anglia
# 270  2024-08  7.756250  East Anglia
# 271  2024-09  7.761111  East Anglia
#
# [272 rows x 3 columns]

# %%
dfEM = df.loc[df['region'] == 'East Midlands']
EM_average = dfEM.groupby('month')['price'].mean()
EM_average = EM_average.to_frame()
EM_average = EM_average.reset_index()
EM_average['area'] = 'East Midlands'

EM_average
# Out:
#        month     price           area
# 0    2002-02  4.225000  East Midlands
# 1    2002-03  4.111111  East Midlands
# 2    2002-04  4.122222  East Midlands
# 3    2002-05  4.090000  East Midlands
# 4    2002-06  4.090000  East Midlands
# ..       ...       ...            ...
# 267  2024-05  6.985000  East Midlands
# 268  2024-06  7.289000  East Midlands
# 269  2024-07  7.289000  East Midlands
# 270  2024-08  7.324000  East Midlands
# 271  2024-09  7.354000  East Midlands
#
# [272 rows x 3 columns]

# %%
dfWM = df.loc[df['region'] == 'West Midlands']
WM_average = dfWM.groupby('month')['price'].mean()
WM_average = WM_average.to_frame()
WM_average = WM_average.reset_index()
WM_average['area'] = 'West Midlands'

WM_average
# Out:
#        month     price           area
# 0    2002-02  4.300000  West Midlands
# 1    2002-03  4.390909  West Midlands
# 2    2002-04  4.400000  West Midlands
# 3    2002-05  4.908333  West Midlands
# 4    2002-06  4.908333  West Midlands
# ..       ...       ...            ...
# 267  2024-05  7.681818  West Midlands
# 268  2024-06  7.681818  West Midlands
# 269  2024-07  7.718182  West Midlands
# 270  2024-08  7.718182  West Midlands
# 271  2024-09  7.718182  West Midlands
#
# [272 rows x 3 columns]

# %%
dfYH = df.loc[df['region'] == 'Yorkshire & Humber']
YH_average = dfYH.groupby('month')['price'].mean()
YH_average = YH_average.to_frame()
YH_average = YH_average.reset_index()
YH_average['area'] = 'Yorkshire & Humber'


YH_average
# Out:
#        month     price                area
# 0    2002-02  4.128571  Yorkshire & Humber
# 1    2002-03  4.128571  Yorkshire & Humber
# 2    2002-04  4.164286  Yorkshire & Humber
# 3    2002-05  4.256250  Yorkshire & Humber
# 4    2002-06  4.227778  Yorkshire & Humber
# ..       ...       ...                 ...
# 267  2024-05  7.258333  Yorkshire & Humber
# 268  2024-06  7.258333  Yorkshire & Humber
# 269  2024-07  7.258333  Yorkshire & Humber
# 270  2024-08  7.490909  Yorkshire & Humber
# 271  2024-09  7.490909  Yorkshire & Humber
#
# [272 rows x 3 columns]

# %%
dfNW = df.loc[df['region'] == 'North West']
NW_average = dfNW.groupby('month')['price'].mean()
NW_average = NW_average.to_frame()
NW_average = NW_average.reset_index()
NW_average['area'] = 'North West'

NW_average
# Out:
#        month     price        area
# 0    2002-02  4.143750  North West
# 1    2002-03  4.121875  North West
# 2    2002-04  4.120588  North West
# 3    2002-05  4.121875  North West
# 4    2002-06  4.134375  North West
# ..       ...       ...         ...
# 267  2024-05  7.022667  North West
# 268  2024-06  7.002500  North West
# 269  2024-07  7.002500  North West
# 270  2024-08  7.052500  North West
# 271  2024-09  7.071250  North West
#
# [272 rows x 3 columns]

# %%
dfN = df.loc[df['region'] == 'North']
N_average = dfN.groupby('month')['price'].mean()
N_average = N_average.to_frame()
N_average = N_average.reset_index()
N_average['area'] = 'North'

N_average
# Out:
#        month     price   area
# 0    2002-02  4.412500  North
# 1    2002-03  4.412500  North
# 2    2002-04  4.462500  North
# 3    2002-05  4.462500  North
# 4    2002-06  4.462500  North
# ..       ...       ...    ...
# 267  2024-05  9.100000  North
# 268  2024-06  9.100000  North
# 269  2024-07  9.166667  North
# 270  2024-08  9.200000  North
# 271  2024-09  9.350000  North
#
# [272 rows x 3 columns]

# %%
dfWales = df.loc[df['region'] == 'Wales']
Wales_average = dfWales.groupby('month')['price'].mean()
Wales_average = Wales_average.to_frame()
Wales_average = Wales_average.reset_index()
Wales_average['area'] = 'Wales'

Wales_average
# Out:
#        month     price   area
# 0    2002-02  3.716667  Wales
# 1    2002-03  3.783333  Wales
# 2    2002-04  3.800000  Wales
# 3    2002-05  3.828571  Wales
# 4    2002-06  3.828571  Wales
# ..       ...       ...    ...
# 267  2024-05  6.890000  Wales
# 268  2024-06  6.890000  Wales
# 269  2024-07  7.025000  Wales
# 270  2024-08  6.930000  Wales
# 271  2024-09  7.025000  Wales
#
# [272 rows x 3 columns]

# %%
dfScotland = df.loc[df['region'] == 'Scotland']
Scotland_average = dfScotland.groupby('month')['price'].mean()
Scotland_average = Scotland_average.to_frame()
Scotland_average = Scotland_average.reset_index()
Scotland_average['area'] = 'Scotland'

Scotland_average
# Out:
#        month     price      area
# 0    2002-02  4.350000  Scotland
# 1    2002-03  4.315000  Scotland
# 2    2002-04  4.116667  Scotland
# 3    2002-05  4.116667  Scotland
# 4    2002-06  4.335000  Scotland
# ..       ...       ...       ...
# 267  2024-05  7.562727  Scotland
# 268  2024-06  7.562727  Scotland
# 269  2024-07  7.571818  Scotland
# 270  2024-08  7.876667  Scotland
# 271  2024-09  7.779000  Scotland
#
# [272 rows x 3 columns]

# %%
dfNI = df.loc[df['region'] == 'Northern Ireland']
NI_average = dfNI.groupby('month')['price'].mean()
NI_average = NI_average.to_frame()
NI_average = NI_average.reset_index()
NI_average['area'] = 'Northern Ireland'

NI_average
# Out:
#        month     price              area
# 0    2002-02  4.783333  Northern Ireland
# 1    2002-03  4.650000  Northern Ireland
# 2    2002-04  4.400000  Northern Ireland
# 3    2002-05  4.400000  Northern Ireland
# 4    2002-06  4.390000  Northern Ireland
# ..       ...       ...               ...
# 266  2024-05  7.720000  Northern Ireland
# 267  2024-06  7.720000  Northern Ireland
# 268  2024-07  7.720000  Northern Ireland
# 269  2024-08  7.760000  Northern Ireland
# 270  2024-09  7.760000  Northern Ireland
#
# [271 rows x 3 columns]

# %%
dfaverage_prices = pd.concat([London_average, SE_average, SW_average, EA_average, EM_average, WM_average, YH_average, NW_average, N_average, Wales_average, Scotland_average, NI_average], axis=0, ignore_index=True)
dfaverage_prices

dfaverage_prices.to_csv('average_prices.csv', index=False)
